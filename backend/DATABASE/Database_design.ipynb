# %%
import pandas as pd

# %%
import sqlite3
conn = sqlite3.connect('MovieFinder.db')
c= conn.cursor()


c.execute("""CREATE TABLE Movie(
                mid integer PRIMARY KEY,
                name text,
                description text,
                region text,
                released_date text,
                director_id integer,
                FOREIGN KEY (director_id) REFERENCES person (pid)
                )""")
c.execute("""CREATE TABLE user(
                uid integer PRIMARY KEY,
                name text,
                password text,
                profile_photo BLOB
                )""")
c.execute("""CREATE TABLE person(
                pid integer PRIMARY KEY,
                name text
                )""")


c.execute("""CREATE TABLE cast(
                castID integer,
                movieID integer,
                FOREIGN KEY (castID) REFERENCES person (pid),
                FOREIGN KEY (movieID) REFERENCES Movie (mid)
                )""")


c.execute("""CREATE TABLE review(
                userID integer,
                movieID integer,
                review_comment text,
                rating integer,
                date text,
                FOREIGN KEY (userID) REFERENCES user (uid),
                FOREIGN KEY (movieID) REFERENCES Movie (mid)
                )""")
c.execute("""CREATE TABLE watch_history(
                userID integer,
                movieID integer,
                watch_date,
                FOREIGN KEY (userID) REFERENCES user (uid),
                FOREIGN KEY (movieID) REFERENCES Movie (mid)
                )""")
c.execute("""CREATE TABLE wish_list(
                userID integer,
                movieID integer,
                FOREIGN KEY (userID) REFERENCES user (uid),
                FOREIGN KEY (movieID) REFERENCES Movie (mid)
                )""")
c.execute("""CREATE TABLE movie_genre(
                movieID integer,
                genre_type text,
                FOREIGN KEY (movieID) REFERENCES Movie (mid)
                )""")
c.execute("""CREATE TABLE user_banned_list(
                userID integer,
                banned_user_ID integer,
                FOREIGN KEY (userID) REFERENCES user (uid)
                )""")


c.execute("""CREATE TABLE Movie_Posters(
                movieID integer,
                poster BLOB,
                FOREIGN KEY (movieID) REFERENCES Movie (mid)
                )""")


conn.commit()
conn.close()

# %%
def insertintoMoviesTable(mid,name,description,region,released_date,director_id):
    sqliteConnection = sqlite3.connect('MovieFinder.db')
    cursor = sqliteConnection.cursor()
    sqlite_insert_with_param = """INSERT INTO Movie
        (mid,name,description,region,released_date,director_id) 
        VALUES (?, ?, ?, ?, ?,?);""" 
    data_tuple = (mid,name,description,region,released_date,director_id)
    cursor.execute(sqlite_insert_with_param, data_tuple)       
    sqliteConnection.commit()      
    cursor.close()
    
def convertToBinaryData(filename):
    with open(filename, 'rb') as file:
        blobData = file.read()
    return blobData
    
    
def insertintoPersonTable(pid,name):
    sqliteConnection = sqlite3.connect('MovieFinder.db')
    cursor = sqliteConnection.cursor()
    sqlite_insert_with_param = """INSERT INTO person
        (pid,name) 
        VALUES (?, ?);""" 
    data_tuple = (pid,name)
    cursor.execute(sqlite_insert_with_param, data_tuple)       
    sqliteConnection.commit()      
    cursor.close()
    
    
def insertintocast(castID , movieID):
    sqliteConnection = sqlite3.connect('MovieFinder.db')
    cursor = sqliteConnection.cursor()
    sqlite_insert_with_param = """INSERT INTO cast
        (castID , movieID) 
        VALUES (?, ?);""" 
    data_tuple = (castID , movieID)
    cursor.execute(sqlite_insert_with_param, data_tuple)       
    sqliteConnection.commit()      
    cursor.close()
    
def Insertintoreview( userID ,movieID ,review_comment,rating,date):
    sqliteConnection = sqlite3.connect('MovieFinder.db')
    cursor = sqliteConnection.cursor()
    sqlite_insert_with_param = """INSERT INTO review
        (userID ,movieID ,review_comment,rating,date) 
        VALUES (?, ?,?,?,?);""" 
    data_tuple = (userID ,movieID ,review_comment,rating,date)
    cursor.execute(sqlite_insert_with_param, data_tuple)       
    sqliteConnection.commit()      
    cursor.close()
    
def insertintowatch_history(userID , movieID ,watch_date):
    sqliteConnection = sqlite3.connect('MovieFinder.db')
    cursor = sqliteConnection.cursor()
    sqlite_insert_with_param = """INSERT INTO watch_history
        (userID , movieID ,watch_date) 
        VALUES (?, ?,?);""" 
    data_tuple = (userID , movieID ,watch_date)
    cursor.execute(sqlite_insert_with_param, data_tuple)       
    sqliteConnection.commit()      
    cursor.close()   
def insertintowish_list(userID , movieID):
    sqliteConnection = sqlite3.connect('MovieFinder.db')
    cursor = sqliteConnection.cursor()
    sqlite_insert_with_param = """INSERT INTO wish_list
        (userID , movieID) 
        VALUES (?, ?);""" 
    data_tuple = (userID , movieID )
    cursor.execute(sqlite_insert_with_param, data_tuple)       
    sqliteConnection.commit()      
    cursor.close()      
def insertintomovie_genre(movieID ,genre_type):
    sqliteConnection = sqlite3.connect('MovieFinder.db')
    cursor = sqliteConnection.cursor()
    sqlite_insert_with_param = """INSERT INTO movie_genre
        (movieID ,genre_type)
        VALUES (?, ?);""" 
    data_tuple = (movieID ,genre_type )
    cursor.execute(sqlite_insert_with_param, data_tuple)       
    sqliteConnection.commit()      
    cursor.close()      
def insertintouser_banned_list( userID,banned_user_ID):
    sqliteConnection = sqlite3.connect('MovieFinder.db')
    cursor = sqliteConnection.cursor()
    sqlite_insert_with_param = """INSERT INTO user_banned_list
        ( userID,banned_user_ID)
        VALUES (?, ?);""" 
    data_tuple = (userID,banned_user_ID)
    cursor.execute(sqlite_insert_with_param, data_tuple)       
    sqliteConnection.commit()      
    cursor.close()     
def convertToBinaryData(filename):
    with open(filename, 'rb') as file:
        blobData = file.read()
    return blobData


def insertintoUserTable(uid,name,password,profile_photo):
    sqliteConnection = sqlite3.connect('MovieFinder.db')
    cursor = sqliteConnection.cursor()
    sqlite_insert_with_param = """INSERT INTO user
        (uid,name,password,profile_photo) 
        VALUES (?, ?, ?, ?);""" 
    Photo = convertToBinaryData(profile_photo)
    data_tuple = (uid,name,password,Photo)
    cursor.execute(sqlite_insert_with_param, data_tuple)       
    sqliteConnection.commit()      
    cursor.close()
def insertintopostersTable(movieID,poster):
    sqliteConnection = sqlite3.connect('MovieFinder.db')
    cursor = sqliteConnection.cursor()
    sqlite_insert_with_param = """INSERT INTO Movie_Posters
        (movieID,poster) 
        VALUES (?, ?);""" 
    Photo = convertToBinaryData(poster)
    data_tuple = (movieID,Photo)
    cursor.execute(sqlite_insert_with_param, data_tuple)       
    sqliteConnection.commit()      
    cursor.close()

# %%
insertintouser_banned_list(1,1)
movies_df=pd.read_csv('moviesfinal.csv')

# %%
counter = 1
for index,row in movies_df.iterrows():
    #insertVaribleIntoTable(id = counter, MovieName=row['original_title'] ,ReleasedDate= row['release_date'] ,WebsiteName = '' ,Cast=str(row['cast_final']) ,Director = '' ,Genre = row['genre_final']  ,Rating=0 ,Reviews='' ,Region=row['region_final'] )
    counter +=1
    insertintoMoviesTable(mid=row['movie_id'],name=row['Movie_name'],description=row['tagline'],region=str(row['countries']),released_date=row['release_date'],director_id= row['directorID'])
    insertintomovie_genre(movieID=row['movie_id'],genre_type=row['genre_names'])

# %%
insertintopostersTable(19995,"posters/19995_avatar.jpg")
insertintopostersTable(285,"posters/285_pirates.jpg")

# %%
Insertintoreview( 1 ,19995 ,'Good',5,'29/12/19')
Insertintoreview( 1 ,285 ,"Nice",7,'26/5/20')
Insertintoreview( 1 ,19995 ,"None",9,'3/4/19')

# %%
insertintoUserTable(1,'Sri Vyshnavi','hjgdssrsj9076',"profiles/1")
insertintoUserTable(2,'Pattrick','joigjkiophgp544',"profiles/2.png")
insertintoUserTable(3,'Zijian','dewygoqwihf3',"profiles/3")
insertintoUserTable(4,'Mingkai','dfhjfksuf',"profiles/4.jpg")

# %%
sqliteConnection = sqlite3.connect('MovieFinder.db')
cursor = sqliteConnection.cursor()
print("Connected to SQLite")
sqlite_select_query = """SELECT * from Movie"""
cursor.execute(sqlite_select_query)
records = cursor.fetchall()
print(records)
# Out:
# Connected to SQLite
# [(5, 'Four Rooms', "Twelve outrageous guests. Four scandalous requests. And one lone bellhop, in his first day on the job, who's in for the wildest New year's Eve of his life.", "['United States of America']", '1995-12-09', 3110), (11, 'Star Wars', 'A long time ago in a galaxy far, far away...', "['United States of America']", '1977-05-25', 1), (12, 'Finding Nemo', "There are 3.7 trillion fish in the ocean, they're looking for one.", "['United States of America']", '2003-05-30', 7), (13, 'Forrest Gump', "The world will never be the same, once you've seen it through the eyes of Forrest Gump.", "['United States of America']", '1994-07-06', 24), (14, 'American Beauty', 'Look closer.', "['United States of America']", '1999-09-15', 39), (16, 'Dancer in the Dark', "You don't need eyes to see.", "['Argentina', 'Denmark', 'Finland', 'France', 'Germany', 'Iceland', 'Italy', 'Netherlands', 'Norway', 'Sweden', 'United Kingdom', 'United States of America']", '2000-05-17', 42), (18, 'The Fifth Element', 'There is no future without it.', "['France']", '1997-05-07', 59), (19, 'Metropolis', 'There can be no understanding between the hands and the brain unless the heart acts as mediator.', "['Germany']", '1927-01-10', 68), (20, 'My Life Without Me', None, "['Canada', 'Spain']", '2003-03-07', 90), (22, 'Pirates of the Caribbean: The Curse of the Black Pearl', 'Prepare to be blown out of the water.', "['United States of America']", '2003-07-09', 1704), (24, 'Kill Bill: Vol. 1', 'Go for the kill.', "['United States of America']", '2003-10-10', 138), (25, 'Jarhead', 'Welcome to the suck.', "['Germany', 'United States of America']", '2005-11-04', 39), (28, 'Apocalypse Now', 'This is the end...', "['United States of America']", '1979-08-15', 1776), (33, 'Unforgiven', 'Some legends will never be forgotten. Some wrongs can never be forgiven.', "['United States of America']", '1992-08-07', 190), (35, 'The Simpsons Movie', 'See our family. And feel better about yours.', "['United States of America']", '2007-07-25', 197), (38, 'Eternal Sunshine of the Spotless Mind', 'You can erase someone from your mind. Getting them out of your heart is another story.', "['United States of America']", '2004-03-19', 201), (55, 'Amores perros', 'Love. Betrayal. Death.', "['Mexico']", '2000-06-16', 223), (58, "Pirates of the Caribbean: Dead Man's Chest", 'Jack is back!', "['Jamaica', 'United States of America', 'Bahamas', 'Dominica']", '2006-06-20', 1704), (59, 'A History of Violence', 'Tom Stall had the perfect life... until he became a hero.', "['United States of America', 'Canada', 'Germany']", '2005-09-23', 224), (62, '2001: A Space Odyssey', 'An epic drama of adventure and exploration', "['United States of America', 'United Kingdom']", '1968-04-10', 240), (65, '8 Mile', 'Every moment is another chance.', "['United States of America']", '2002-11-08', 323), (66, 'Absolute Power', 'Corrupts Absolutely.', "['United States of America']", '1997-02-14', 190), (68, 'Brazil', "It's only a state of mind.", "['United Kingdom']", '1985-02-20', 280), (69, 'Walk the Line', 'Love is a burning thing.', "['Germany', 'United States of America']", '2005-09-13', 366), (70, 'Million Dollar Baby', 'Beyond his silence, there is a past. Beyond her dreams, there is a feeling. Beyond hope, there is a memory. Beyond their journey, there is a love.', "['United States of America']", '2004-12-15', 190), (71, 'Billy Elliot', 'Inside every one of us is a special talent waiting to come out. The trick is finding it.', "['France', 'United Kingdom']", '2000-05-18', 468), (73, 'American History X', 'Some Legacies Must End.', "['United States of America']", '1998-10-30', 814), (74, 'War of the Worlds', "They're already here.", "['United States of America']", '2005-06-28', 488), (75, 'Mars Attacks!', "Nice planet. We'll take it!", "['United States of America']", '1996-12-12', 510), (76, 'Before Sunrise', 'Can the greatest romance of your life last only one night?', "['Austria', 'Switzerland', 'United Stat ...
